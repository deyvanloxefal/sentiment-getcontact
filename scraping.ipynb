# %%
# !pip install google_play_scraper
import pandas as pd
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import numpy as np
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
result, continuation_token = reviews(
    'app.source.getcontact',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=50000,
    filter_score_with= None
)

# %%
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId         userName  \
# 0  9fef6bfa-c989-45ad-ae13-908ac6ee279b  Pengguna Google
# 1  9cdd645c-b934-4d22-abd0-32341313606d  Pengguna Google
# 2  1253e9cc-5398-44ca-9b2c-b752511f6f40  Pengguna Google
# 3  def61f04-752f-49a8-b476-9037a868c12b  Pengguna Google
# 4  2004649f-1c80-411a-a7b7-14fabfe267d7  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Sangat kurang dikarenakan tidak bisa berhenti ...      1            300
# 1  sebenarnya sangat membantu tetapi sekarang fit...      2            217
# 2  Duh sayang banget sekarang setiap fiturnya har...      1           2797
# 3  Sayang banget harus bayar premium per-bulannya...      1            300
# 4  Sebenernya sangat membantu ini aplikasi, tapi ...      1             69
#
#   reviewCreatedVersion                  at  \
# 0                7.4.0 2025-01-07 23:54:26
# 1                7.4.0 2025-01-02 19:42:53
# 2                7.4.0 2024-12-24 07:28:56
# 3                7.4.0 2024-12-27 12:04:06
# 4                7.5.0 2025-01-18 10:45:40
#
#                                         replyContent           repliedAt  \
# 0  Halo, Terima kasih telah menghubungi kami. Kam... 2025-01-08 08:54:04
# 1  Hai,\nKami telah menerima umpan balik Anda dan... 2025-01-02 14:32:33
# 2  Tim Getcontact mengucapkan terima kasih atas k... 2024-12-24 09:09:51
# 3  Halo,\nTim Getcontact telah saran dari Anda da... 2024-12-28 17:02:08
# 4  Halo, Silahkan lengkapi formulir berikut dan s... 2025-01-18 16:22:08
#
#   appVersion
# 0      7.4.0
# 1      7.4.0
# 2      7.4.0
# 3      7.4.0
# 4      7.5.0

# %%
data = data[['content']]
data.head()
# Out:
#                                              content
# 0  Sangat kurang dikarenakan tidak bisa berhenti ...
# 1  sebenarnya sangat membantu tetapi sekarang fit...
# 2  Duh sayang banget sekarang setiap fiturnya har...
# 3  Sayang banget harus bayar premium per-bulannya...
# 4  Sebenernya sangat membantu ini aplikasi, tapi ...

# %%
len(data)
# Out:
# 50000

# %%
data.tail()
# Out:
#                                                  content
# 49995  Bintang 3 dulu. Kalo suka kembali lagi kasih r...
# 49996     Parah bgt skr gk bisa liat penandaan harus pro
# 49997  Ini aja loging aja susah gak layak pakai login...
# 49998     sangat berguna untuk melacak nomer tak dikenal
# 49999  Sekarang banyak banget penipuan harus download...

# %%
data.to_csv("Ulasan Getcontact.csv", index = False  , encoding='utf-8')
