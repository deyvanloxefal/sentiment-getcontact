# %%
# !pip install google_play_scraper
import pandas as pd
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import numpy as np
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %%
result, continuation_token = reviews(
    'app.source.getcontact',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=50000,
    filter_score_with= None
)

# %%
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId         userName  \
# 0  9fef6bfa-c989-45ad-ae13-908ac6ee279b  Pengguna Google
# 1  9cdd645c-b934-4d22-abd0-32341313606d  Pengguna Google
# 2  1253e9cc-5398-44ca-9b2c-b752511f6f40  Pengguna Google
# 3  def61f04-752f-49a8-b476-9037a868c12b  Pengguna Google
# 4  2004649f-1c80-411a-a7b7-14fabfe267d7  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Sangat kurang dikarenakan tidak bisa berhenti ...      1            361
# 1  sebenarnya sangat membantu tetapi sekarang fit...      2            232
# 2  Duh sayang banget sekarang setiap fiturnya har...      1           2815
# 3  Sayang banget harus bayar premium per-bulannya...      1            311
# 4  Sebenernya sangat membantu ini aplikasi, tapi ...      1             74
#
#   reviewCreatedVersion                  at  \
# 0                7.4.0 2025-01-07 23:54:26
# 1                7.4.0 2025-01-02 19:42:53
# 2                7.4.0 2024-12-24 07:28:56
# 3                7.4.0 2024-12-27 12:04:06
# 4                7.5.0 2025-01-18 10:45:40
#
#                                         replyContent           repliedAt  \
# 0  Halo, Terima kasih telah menghubungi kami. Kam... 2025-01-08 08:54:04
# 1  Hai,\nKami telah menerima umpan balik Anda dan... 2025-01-02 14:32:33
# 2  Tim Getcontact mengucapkan terima kasih atas k... 2024-12-24 09:09:51
# 3  Halo,\nTim Getcontact telah saran dari Anda da... 2024-12-28 17:02:08
# 4  Halo, Silahkan lengkapi formulir berikut dan s... 2025-01-18 16:22:08
#
#   appVersion
# 0      7.4.0
# 1      7.4.0
# 2      7.4.0
# 3      7.4.0
# 4      7.5.0

# %%
len(data)
# Out:
# 50000

# %%
data.tail()
# Out:
#                                    reviewId        userName  \
# 49995  ca637815-0c90-4f6e-8835-c77c2f259ff8         davv ar
# 49996  654ac55d-784d-4850-830a-d99fc5c4ebf6          ndwnvi
# 49997  527a4f04-ff0c-4b7d-8ecb-565486e51cd5       Zulfa Tul
# 49998  13b09dfc-4a36-4bdd-a20e-2b753cc47b57  Cantiknya Ayah
# 49999  bbf26b1a-ed9d-4bff-a8ab-b288bbe56f99         IzaL 15
#
#                                                userImage  \
# 49995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 49996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 49997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 49998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 49999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 49995  Bintang 3 dulu. Kalo suka kembali lagi kasih r...      3
# 49996     Parah bgt skr gk bisa liat penandaan harus pro      1
# 49997  Ini aja loging aja susah gak layak pakai login...      1
# 49998     sangat berguna untuk melacak nomer tak dikenal      5
# 49999  Sekarang banyak banget penipuan harus download...      5
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 49995              0                5.7.0 2022-06-03 16:34:45         None
# 49996              0                 None 2024-07-17 03:51:13         None
# 49997              0                 None 2023-11-23 14:42:31         None
# 49998              0                 None 2023-11-23 22:12:42         None
# 49999              0                 None 2023-06-28 03:56:32         None
#
#       repliedAt appVersion
# 49995       NaT      5.7.0
# 49996       NaT       None
# 49997       NaT       None
# 49998       NaT       None
# 49999       NaT       None

# %%
data.to_csv("Ulasan Getcontact.csv", index = False  , encoding='utf-8')
